# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
zip_path = 'gdrive/MyDrive/SER/datasets/RAVDESS/Audio_Speech_Actors_01-24.zip'
unzip_path = 'gdrive/MyDrive/SER/datasets/RAVDESS/Audio_Speech_Actors_01-24/'
# !unzip -q -d $unzip_path $zip_path

# %%
zip_path = 'gdrive/MyDrive/SER/datasets/RAVDESS/Audio_Song_Actors_01-24.zip'
unzip_path = 'gdrive/MyDrive/SER/datasets/RAVDESS/Audio_Song_Actors_01-24/'
# !unzip -q -d $unzip_path $zip_path

# %%
drive.flush_and_unmount()
